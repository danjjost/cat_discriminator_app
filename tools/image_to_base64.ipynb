# %% [markdown]
# ### 🔧 Config

# %%
import base64
#image_path = '../data/staging/bathroom-cat/0a9c0a7f9b1342eab2e8d7f693b71bb9.jpg'
image_path = '../data/bathroom-cat-256x256/0a9c0a7f9b1342eab2e8d7f693b71bb9.jpg'

# %% [markdown]
# ### 📃 Parse

# %%
def image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode('utf-8')
    return encoded_string

base64_string = image_to_base64(image_path)
print(base64_string)
# Out:
# ...
